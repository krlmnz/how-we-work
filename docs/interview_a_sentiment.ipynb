# %%
# Interview sentiment

# %%
import pandas as pd
import string
import seaborn as sns
import matplotlib.pyplot as plt
import collections
import nltk
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer
from collections import Counter

# %%
data = pd.read_csv('interview-a.csv')
print(data.dtypes)
print("--------DataType of DataFrame after converting---------")
df=data.convert_dtypes()
print(df.dtypes)
# Out:
# timecode      object
# transcript    object
# dtype: object
# --------DataType of DataFrame after converting---------
# timecode      string[python]
# transcript    string[python]
# dtype: object

# %%
df
# Out:
#                       timecode  \
# 0    00:00:00.00 - 00:00:19.51
# 1    00:00:19.51 - 00:00:28.62
# 2    00:00:28.63 - 00:00:31.53
# 3    00:00:31.54 - 00:01:07.22
# 4    00:01:07.23 - 00:01:08.62
# ..                         ...
# 249  00:46:01.78 - 00:46:02.41
# 250  00:46:02.42 - 00:46:04.92
# 251  00:46:05.72 - 00:46:06.50
# 252  00:46:06.83 - 00:46:07.54
# 253  00:46:07.55 - 00:46:08.30
#
#                                             transcript
# 0    it was very official, this session is now bein...
# 1    We're just very interested in, you know how yo...
# 2      Um so yeah, I'll just introduce myself quickly.
# 3    I am a product designer, I have worked in the ...
# 4                                                Sure.
# ..                                                 ...
# 249                                              Cool.
# 250                     Yeah, well, thank you so much.
# 251                                           Alright.
# 252                                           You too.
# 253                                               Bye.
#
# [254 rows x 2 columns]

# %%
nltk.download('vader_lexicon')
#run this cell to see how the sentiment analyzer works
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/karol/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#create a new column called polarity and apply the sia method to the clean_lyric column with a lambda expression
df['polarity'] = df['transcript'].apply(lambda x: sia.polarity_scores(x))
df.head()
# Out:
#                     timecode  \
# 0  00:00:00.00 - 00:00:19.51
# 1  00:00:19.51 - 00:00:28.62
# 2  00:00:28.63 - 00:00:31.53
# 3  00:00:31.54 - 00:01:07.22
# 4  00:01:07.23 - 00:01:08.62
#
#                                           transcript  \
# 0  it was very official, this session is now bein...
# 1  We're just very interested in, you know how yo...
# 2    Um so yeah, I'll just introduce myself quickly.
# 3  I am a product designer, I have worked in the ...
# 4                                              Sure.
#
#                                             polarity
# 0  {'neg': 0.158, 'neu': 0.729, 'pos': 0.114, 'co...
# 1  {'neg': 0.0, 'neu': 0.88, 'pos': 0.12, 'compou...
# 2  {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'comp...
# 3  {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'comp...
# 4  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...

# %%
#run this cell to transform the polarity dictionary into columns of the DataFrame
df[['neg', 'neu', 'pos', 'compound']] = df['polarity'].apply(pd.Series)
df.drop('polarity', axis=1)
# Out:
#                       timecode  \
# 0    00:00:00.00 - 00:00:19.51
# 1    00:00:19.51 - 00:00:28.62
# 2    00:00:28.63 - 00:00:31.53
# 3    00:00:31.54 - 00:01:07.22
# 4    00:01:07.23 - 00:01:08.62
# ..                         ...
# 249  00:46:01.78 - 00:46:02.41
# 250  00:46:02.42 - 00:46:04.92
# 251  00:46:05.72 - 00:46:06.50
# 252  00:46:06.83 - 00:46:07.54
# 253  00:46:07.55 - 00:46:08.30
#
#                                             transcript    neg    neu    pos  \
# 0    it was very official, this session is now bein...  0.158  0.729  0.114
# 1    We're just very interested in, you know how yo...  0.000  0.880  0.120
# 2      Um so yeah, I'll just introduce myself quickly.  0.000  0.737  0.263
# 3    I am a product designer, I have worked in the ...  0.000  0.872  0.128
# 4                                                Sure.  0.000  0.000  1.000
# ..                                                 ...    ...    ...    ...
# 249                                              Cool.  0.000  0.000  1.000
# 250                     Yeah, well, thank you so much.  0.000  0.306  0.694
# 251                                           Alright.  0.000  0.000  1.000
# 252                                           You too.  0.000  1.000  0.000
# 253                                               Bye.  0.000  1.000  0.000
#
#      compound
# 0     -0.6597
# 1      0.4576
# 2      0.3597
# 3      0.8748
# 4      0.3182
# ..        ...
# 249    0.3182
# 250    0.7003
# 251    0.2500
# 252    0.0000
# 253    0.0000
#
# [254 rows x 6 columns]

# %%
#df.sort_values(by='neg', ascending=False)
#df.sort_values(by='pos', ascending=False)
#df.sort_values(by='compound', ascending=False)

# %%
df.to_csv('interview_a_sentiment.csv')
